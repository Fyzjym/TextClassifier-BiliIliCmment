# %% [markdown]
# # carComment 处理
#
# ## 过滤掉该数据集

# %%
import pandas as pd

# %%
pd_car_comm = pd.read_csv('./rowData/carComment_pso_neg_03.csv')

# %%
car_pos = pd_car_comm[pd_car_comm.label == 1]
car_neg = pd_car_comm[pd_car_comm.label == 0]

# %%
car_pos_comments = car_pos['text']
car_neg_comments = car_neg['text']

# %%
out = open('./data/pos_car.csv', 'w')
for comm in car_pos_comments:
    out.write(comm + '\n')

out = open('./data/neg_car.csv', 'w')
for comm in car_neg_comments:
    out.write(comm + '\n')

# %% [markdown]
# # goodsComment_01 处理

# %%
pd_goods_comm_01 = pd.read_csv('./rowData/goodsComment_pos_neg_01.txt', names=['content','split','label'])

# %%
goods_01_pos = pd_goods_comm_01[pd_goods_comm_01.label == 1]
goods_01_neg = pd_goods_comm_01[pd_goods_comm_01.label == 0]

# %%
goods_01_neg_comments = goods_01_neg['content']
goods_01_pos_comments = goods_01_pos['content']

# %%
out = open('./data/pos_goods_01.csv', 'w')
for comm in goods_01_pos_comments:
    out.write(str(comm) + '\n')

out = open('./data/neg_goods_01.csv', 'w')
for comm in goods_01_neg_comments:
    out.write(str(comm) + '\n')

# %% [markdown]
# # goodsComment_02 处理

# %%
pd_goods_comm_02 = pd.read_csv('./rowData/goodsComment_pos_neg_02.txt', sep='\t', names=['order', 'content', 'label'])

# %%
# 这个数据集有三个标签 0：中性（模糊） 1:积极 2:消极，  这里只取 标签为 1、2
goods_02_pos = pd_goods_comm_02[pd_goods_comm_02.label == 1]
goods_02_neg = pd_goods_comm_02[pd_goods_comm_02.label == 2]

# %%
goods_02_neg_comments = goods_02_neg['content']
goods_02_pos_comments = goods_02_pos['content']

# %%
out = open('./data/pos_goods_02.csv', 'w')
for comm in goods_02_pos_comments:
    out.write(str(comm) + '\n')

out = open('./data/neg_goods_02.csv', 'w')
for comm in goods_02_neg_comments:
    out.write(str(comm) + '\n')

# %% [markdown]
# # bookComment 处理
#
# ## 过滤掉该数据集

# %%
pd_book_comm_pos = pd.read_csv('./rowData/bookCommentPos_05.csv', sep='\t')
pd_book_comm_neg = pd.read_csv('./rowData/bookCommentNeg_04.csv', sep='\t')

# %%
book_comm_pos = pd_book_comm_pos['content']
book_comm_neg = pd_book_comm_neg['content']

# %%
out = open('./data/pos_book.csv', 'w')
for comm in book_comm_pos:
    out.write(str(comm) + '\n')

out = open('./data/neg_book.csv', 'w')
for comm in book_comm_neg:
    out.write(str(comm) + '\n')

# %% [markdown]
# # pos neg 数据集合并处理

# %%
#pd_neg_book = pd.read_csv('./data/neg_book.csv', sep='\t', names=['content'])
#pd_neg_car = pd.read_csv('./data/neg_car.csv', sep='\t', names=['content'])
pd_neg_goods_01 = pd.read_csv('./data/neg_goods_01.csv', sep='\t', names=['content'])
pd_neg_goods_02 = pd.read_csv('./data/neg_goods_02.csv', sep='\t', names=['content'])

#pd_pos_book = pd.read_csv('./data/pos_book.csv', sep='\t', names=['content'])
#pd_pos_car = pd.read_csv('./data/pos_car.csv', sep='\t', names=['content'])
pd_pos_goods_01 = pd.read_csv('./data/pos_goods_01.csv', sep='\t', names=['content'])
pd_pos_goods_02 = pd.read_csv('./data/pos_goods_02.csv', sep='\t', names=['content'])

# %%
neg = []
#for i in pd_neg_book.content:
#    neg.append(i)
#for i in pd_neg_car.content:
#    neg.append(i)
for i in pd_neg_goods_01.content:
    neg.append(i)
for i in pd_neg_goods_02.content:
    neg.append(i)
    
pos = []
#for i in pd_pos_book.content:
#    pos.append(i)
#for i in pd_pos_car.content:
#    pos.append(i)
for i in pd_pos_goods_01.content:
    pos.append(i)
for i in pd_pos_goods_02.content:
    pos.append(i)

# %%
out = open('./data/neg.csv', 'w')
out.write('content' + '\n')
for comm in neg:
    out.write(str(comm) + '\n')
    
out = open('./data/pos.csv', 'w')
out.write('content' + '\n')
for comm in pos:
    out.write(str(comm) + '\n')

# %% [markdown]
# ## 结果

# %%
pd_pos = pd.read_csv('./data/pos.csv', sep='\t')
pd_neg = pd.read_csv('./data/neg.csv', sep='\t')

# %%
pd_pos
# Out:
#                                                  content
# 0                                        整体的感觉还是不错的，，，，，
# 1                                                   裤子很好
# 2                                 很好穿的，冬天穿比较保暖，品质保证，价格实惠
# 3      裤子出去刚好，穿着凉快，面料不错，穿在身上很舒服，夏天穿黑色很百搭，裤子垂感也不错，很好搭配...
# 4                                        鞋子轻便舒服，好穿，值得推荐。
# 5                                            衣服还不错。这个价格值
# 6                                     不错给老公买了好几个了，穿着特别舒服
# 7                         手机收到，过年回家送给爸爸，爸爸超级喜欢，声音很大，外观很美
# 8                                尺寸穿着也合适，推荐朋友过来买！祝店家大卖！！
# 9                                                衣服质量不错哦
# 10                                    第一次玩笔记本 感觉不错 没让我失望
# 11                                            质量不错，穿着舒服。
# 12                  裤子太棒了，裤型非常好，质量也特好，裤子穿起来看着很大方。总之非常满意。
# 13     主机试用过了才评价，效果不错。开机十来秒，反应速度很快。开网页各方面都会顺畅！感谢推荐。客服...
# 14                                             618便宜，还不错
# 15                                      第一次购买收到超意外质量杠杠的好
# 16                                     质量不错！很好！是一次愉快的购物！
# 17                                   不错，不是第一次买了！快递小哥辛苦了！
# 18       刚刚收到，物流很快，昨天晚上下的单，今天中午就到了。鞋子很不错，和商家的图一样，穿起来很舒服。
# 19                   不错还行吧，收到宝贝了，然后打开之后发现也没什么异味，包装很精美，不错
# 20                                         性价比很不错，鞋子也好看的
# 21     再夸一次，京东的物流真的无敌。投递员很贴心。手机质感一流，女儿非常喜欢，通过争取还赠了115...
# 22                                                 穿着很舒服
# 23                                             老公，说挺舒服的！
# 24                                           终于收到我需要的宝贝了
# 25                                    收到鞋，质量很好 ，款式样式大小合适
# 26                      鞋子收到了，昨晚收到，迫不及待的拆开了四川美，上脚，效果真的不错
# 27                                            还不错?就是我太肥了
# 57582  键盘可以适应高速打字，比较出乎意料，可以聊天使用了，比原来的9寸的本确实好。电池的待机时间还...
# 57583               sony的笔记本就是样子漂亮，不过买笔记本这点我觉得非常重要，所以选它了
# 57584  我自己先买了一本,后来又买了2本送给两个最好的朋友,希望他们和我一样从中领悟到生命更加美好的...
#
# [57585 rows x 1 columns]

# %%
pd_neg
# Out:
#                                                  content
# 0                才用就发现相机打开迟钝，半天反应不过来，有时候还会卡出去，他们又不给解决方案。
# 1                                              还没穿二天就起毛了
# 2                坑呢！能教我怎样将双卡和内存卡一起装进去吗？如果不能，说什么支持双卡和SD?-
# 3      诺基亚手机做工质量太差，后壳太垃圾没用几天就掉漆了，为毛要用金属材质，为啥不用陶瓷材质后壳呀...
# 4      非常不满意京东的售后服务，买之前联系客服说由于公司新开，公司增值税发票的开票信息还没出来，要...
# 5                          昨天刚买的手机。手机保修到9月份。还有一次鉴定。这是啥机子
# 6      收到手机后不知道怎么说吧！从下单到收到手机之前心情是兴奋的，收到手机之后糟糕透了，什么东西都...
# 7                               垃圾    在北京呆了3天没动弹    真几把慢
# 8                             好大的味道，放了三四天了那个味都去不了。垃圾货来的。
# 9                                  都还行 买了两个星期左右就便宜了100元了
# 10                                           才买不到三天就降200
# 11                             才用了一个月就花屏，卡死，屏幕闪烁&hellip;
# 12     2299买的6G+64G，今天才发现已经降价到1999，并且还有100的优惠券，买了第二天才...
# 13                                       不好用，屏幕不灵敏，照相不清楚
# 14                                       不好 ? 第一次买 真让人失望
# 15                           这个服务态度很差，我非常不满意，而且老子刚买手机就降价
# 16     屏幕不行，失灵，断触，乱触，图案解锁就很难打开。我很烦。。。。因为触屏游戏也玩不流畅，真心感...
# 17                                         太厚了，冬天穿的么，这不是
# 18     第一、确实是全新未开封的手机，不是京东的自封机。第二、手机外观确实还是那个设计，换成了玻璃材...
# 19                                    屏幕显示效果很一般！！！！其他还好！
# 20                                                物流是真的慢
# 21                                     一个多月屏幕就花成这样了，太气人了
# 22     近六千买的垃圾电脑，开个酷狗，浏览器，还有个360就卡的不行。激活了又不能退。京东几年购物以...
# 23                                        耳机转换器居然漏放了 真**
# 24       对不起，差评没商量，手机收到货屏幕有瑕疵，不知道是屏幕问题还是手机自带贴膜问题，客服没人搭理。
# 25     买了两部 一部64G 另一部32G这款手机前后都是双摄像头一个摄像头就是个摆设 不信你用手指...
# 26                            买贵了，有1598的还有花不到1500的，感觉被骗了
# 27               43码鞋跟40码鞋一样大  跟他沟通  说话还让人不高兴   发货速度还是龟速
# 28                            很失望的一次购物，刚拿到手开机就发烫得厉害，退货了事
# 29                                            。。。。。。。。。。
# ...                                                  ...
# 57409  很一般，服务态度不好，我走的时候有个密封的纸箱子需要帮忙拿下来，我先到前台结帐并找人帮忙拿下...
# 57410  发热量也太大了吧，刚开机没多久，仅上网，机器就很热了，gpu就没有下过50度，cp一直44度...
# 57411      下了订单却没有收到书，郁闷！！！如果没有更新网页在配货时才发现缺货应该及时通知客户才对呀！
# 57412  不得不评价当地政府接待酒店，真是官宦意识浓厚1、关于早餐此次为08年1月28号入住，2月1日...
# 57413                   收到书时,书皮已经褶皱了,感觉很不舒服,希望当当以后能改进!!!
# 57414       我订的行政房，房间很小，而且楼比较旧，除了能上网没觉得跟普标有什么差别。酒店本身也很小。
# 57415  由于五一当天决定出去玩,订晚了,只有三家酒店可选择,就选了这家.优点:酒店在青山湖边,房间要...
# 57416  1、键盘较硬2、没有蓝牙3、A面是个指纹收集板4、声音较小5、随机没有附带光盘6、屏幕效果似...
# 57417  一定要保证最好的送给国际友人，港澳台同胞，把最差的留给百毒不侵的自己人。蒙牛，真的只是蒙牛，...
# 57418    至少我没觉得好看，根本就不吸引我，没什么可笑得，有些词很深辟。书的印刷很不错，内容没介绍的好。
# 57419     怎么书的质量这么差啊！！！封皮很薄而且里面的切割还有碎末一点也不整齐是不是盗版的啊！！！！！
# 57420                            类似的书不会再买了没有实用性，都是宣传吹出来的
# 57421                 C面和外观颜色有点不搭，不送鼠标，包，还得自己买。不过送的也了垃圾。
# 57422  这套书收到时没有折开看就付了钱,后来折开一看这套书不成套,一本少了一本多了,于是及进办理了退...
# 57423    国庆头一天去住，门市价和携程的价一样，豪华房672元还不包早餐。房间设施挺旧得了，感觉很一般。
# 57424                 LINUX下看个电影听歌都会卡偏偏装XP那么麻烦我运气一直都不好!!
# 57425                      无吸引力，被书评蒙骗了，不值一看。只是讲道理，无乜实用性！
# 57426              表面漂亮的代价就是指纹收录机，已经让朋友把机器的外表面和内屏都贴了保护膜。
# 57427            特别是关于她和总监同志的感情线一直脱不了琼瑶的小影子,太一厢情愿自我感觉甚好了
# 57428  实在是太失望了，本来希望能够增加词汇量可是打开看后字太小，内容太乱并不适合我这种初级水平，还...
# 57429               酒店确实很差，而且价格很贵！山景房居然就是对着一个小秃山，实在是无语！！
# 57430                               没什么特别还是买个CD、MP3自己练吧！
# 57431                  房间很大味道，服务差，态度差，房单设施差永远不会再去了。差就一个字
# 57432  预装了VISTA，帮朋友买的，朋友不喜欢，我只能用自己的联想OEMXP盘给格了重装。这点联想...
# 57433  房间太旧，卫生间是很多锈迹，房间比较大，大床不错，我喜欢。价格还可以，就是太旧了，不舒服，服...
# 57434  这本书刚开始看还觉得不错，到了后来就觉得内容太乏味了，看了三分之一就不想再继续看下去了。这本...
# 57435                        浪得虚名，一点都不实用。我们平时说细胞基因这些词吗？？
# 57436                 我女儿很喜欢.画面漂亮、有趣，内容也很精彩。连我都很喜欢。值得一读。
# 57437  男友是老外第一次来上海所以选择住的离外滩近的酒店，25号入住一切OK，宾馆周围环境不怎么样就...
# 57438  很遗憾，昨天送来的这本书被我退回，原因是这本书我接收的时候发现书从中间折断，我订了三本书，这...
#
# [57439 rows x 1 columns]
