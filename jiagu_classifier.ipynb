# %%
import jiagu

# %%
text = '你可真是个大好人啊'
sentiment = jiagu.sentiment(text)
print(sentiment)
# Out:
# ('positive', 0.587300588133346)

# %%
help(jiagu.sentiment)
# Out:
# Help on method sentiment in module jiagu.analyze:
#
# sentiment(text) method of jiagu.analyze.Analyze instance

# %%
import pandas as pd
df_pl_content = pd.read_csv('./data/BiliComment_contain20000.csv', sep='\t')
df_pl_content = df_pl_content.content.values.tolist()

for i in df_pl_content[:100]:
    print("".join(i),jiagu.sentiment(i))  # 除了分词还可以过滤下 停用词，写个函数啥的
# Out:
# 也是上过央视哈哈哈哈哈哈 ('positive', 0.7583410491272389)
# 恶意抢注 ('negative', 0.5755185864796883)
# 加油 ('positive', 0.5789473684210525)
# 老爹说过要用魔法对抗魔法        出自《成龙历险记》。 ('negative', 0.9178456724976323)
# 支持维权 ('positive', 0.9207394858693785)
# 身份证不见了还可以去改名吗？急，打算明天去公安局改的，结果身份证不见了，真的想哭，已经成年了，只带户口本可以去改吗？ ('negative', 0.9980548058352456)
# 加油 ('positive', 0.5789473684210525)
# 真他妈的可悲 ('negative', 0.7305767020694016)
# 2507.4w ('negative', 0.6476685249564166)
# 一杯敬死神，一杯敬汉卿。 ('negative', 0.9980888187176247)
# 加油 ('positive', 0.5789473684210525)
# 加油 ('positive', 0.5789473684210525)
# 皮皮虾和b站都关注了 ('negative', 0.6437371648332885)
# 加油⛽️ ('negative', 0.5720825205848049)
# 冲冲冲 ('positive', 0.8156811158764873)
# 这事本身就很荒唐，人家名字也可以注册？呵呵笑死我了，这个部门在干嘛 ('negative', 0.9365304638788896)
# 真的没想到敬汉卿是真名，父母太有才了，取的好好听 ('negative', 0.9991545875579951)
# 第一次三连[OK] ('negative', 0.7020418994874311)
# 太难了up主 ('positive', 0.6353432848487116)
# 一直喜欢敬汉卿大大的视频，支持依法维权，坚决抵制这种不道德的行为。 ('positive', 0.9210095219579241)
# 支持你 ('positive', 0.9087350184081237)
# 敬汉卿你好，我也经常看你的节目，我们也是做商标这块的。刚才查询了一下，目前这个41还不是最要命的，你的35类也被抢注了，现在正在公示，如果35类被抢注，你就不能做广告，彻底凉凉了，希望你能引起共重视，现在赶紧去。35类的商标进行复议 复制自热心网友35类已经在2019.7.13号开始初审公示了，如果在三个月之内，也就是10月13号之前没有人复议的话就通过了，你35类商标如果丢了的话，你彻底就告别这个名字了（复制粘贴评论区）敬汉卿你好，我也经常看你的节目，我们也是做商标这块的。刚才查询了一下，目前这个41还不是最要命的，你的35类也被抢注了，现在正在公示，如果35类被抢注，你就不能做广告，彻底凉凉了，希望你能引起共重视，现在赶紧去。35类的商标进行复议 复制自热心网友35类已经在2019.7.13号开始初审公示了，如果在三个月之内，也就是10月13号之前没有人复议的话就通过了，你35类商标如果丢了的话，你彻底就告别这个名字了（复制粘贴评论区） ('negative', 1.0)
# 抵制非法经营，保护维护自名正当权益，保护姓名并提供法律法规政策支持。敬汉卿，加油！[打call] ('positive', 0.9433411661020344)
# 奥利给 ('positive', 0.746851681597571)
# 加油[微笑] ('positive', 0.7277881123470955)
# 就服你_x1f44d__x1f44d__x1f44d__x1f44d_ ('negative', 0.9868160255072386)
# 嘿嘿 ('positive', 0.7258064516129034)
# 。。。 ('negative', 0.6476685249564166)
# 牛逼 ('negative', 0.7331419686544177)
# 没想到吧我真的叫这名字 ('negative', 0.7153581956727976)
# 三刷这视频 ('positive', 0.7560474266197371)
# 看好 ('positive', 0.8571428571428571)
# 加油 ('positive', 0.5789473684210525)
# up主不要怕，法律会保护你的！ ('negative', 0.8637137265073037)
# [口罩][口罩][口罩] ('negative', 0.9194743534798682)
# 劳资不弄死他 ('negative', 0.8956114438690995)
# Ok ('positive', 0.5)
# 加油 ('positive', 0.5789473684210525)
# 加油 ('positive', 0.5789473684210525)
# 我想知道维权现在结果怎么样了 ('negative', 0.6920410463318625)
# 不看评论区还不知道原来B站有这么多睾粉丝量up。 ('negative', 0.723170654402714)
# 支持 ('positive', 0.9402985074626866)
# 一键三连[害羞] ('negative', 0.9978003842947466)
# 干巴爹，敬汉卿， ('negative', 0.7856452439775298)
# 加油 ('positive', 0.5789473684210525)
# 牛批 ('negative', 0.6108785776810502)
# 那么，我这个叫徐智摩的还是不要出名好了 ('negative', 0.6648765957859966)
# 加油 ('positive', 0.5789473684210525)
# [doge][doge][doge][doge] ('negative', 0.9660535943976123)
# 干屎他们 ('negative', 0.6819954481296341)
# 好 ('positive', 0.5732378854625548)
# 加油 ('positive', 0.5789473684210525)
# 给大家分享一个视频哈，大概内容喷是n年前jhq喝恒河水的事，说这个有可能会引起瘟疫爆发传给中国[热词系列_秀]人家想靠瘟疫＋敬汉卿两个热点词打造爆款呢，前段时间孔雀肉之后又来一波恒河水，下期估计就是喷敬汉卿17年口罩挑战了av89044842[热词系列_可以] ('negative', 0.9999823876137997)
# 186400！ ('negative', 0.5755185864796883)
# 这都是什么破事啊？还敢勒索？ ('negative', 0.9642101148959816)
# 永远支持你 ('positive', 0.9734888504879073)
# 姓名权优先大于商标权，没有任何人有权利让敬汉卿改名，除了他自己 ('negative', 0.9833385680562391)
# 从AV62399999的评论过来的 ('positive', 0.7724858624213664)
# up主为什么我看你的粉丝降到了700多万＠_＠ ('negative', 0.9650886390753866)
# 嗯嗯 ('positive', 0.5)
# 敬汉卿加油！！！！ ('negative', 0.81875958583)
# 已三连 ('negative', 0.5669094356482999)
# 加油哦 ('positive', 0.6371829802183996)
# 支持 ('positive', 0.9402985074626866)
# 加油 ('positive', 0.5789473684210525)
# 加油 ('positive', 0.5789473684210525)
# 哦，嗯，好的。 ('negative', 0.6113327343261088)
# woc447万硬币 ('negative', 0.6540698975055749)
# 加油 ('positive', 0.5789473684210525)
# 加油，up ('negative', 0.5720825205848049)
# 粉丝 ('positive', 0.6666666666666666)
# 加油 ('positive', 0.5789473684210525)
# 新人up打气 ('positive', 0.7436772656803912)
# [热词系列_三连] ('negative', 0.8444653704090833)
# 666 ('positive', 0.5)
# 字体举报。 ('negative', 0.7861636186484156)
# 加油 ('positive', 0.5789473684210525)
# 比如说被papi酱。 ('negative', 0.5531081084298418)
# up主三观太棒了 ('positive', 0.872283345289314)
# [嫌弃] ('negative', 0.9671180066748002)
# C4招待 ('positive', 0.6887343660657357)
# 打卡支持！ ('positive', 0.9625524058826588)
# 支持支持 ('positive', 0.9945640890607034)
# 零粉up猪前来助攻[doge] ('negative', 0.8754159560814343)
# 没问题的。 ('negative', 0.7338552981820984)
# 现在2020年，竟然还有没良心的公司在抢注商标，而且这一次是抢注的火神山医院和雷神山医院的商标，我就只想问你们的良心到哪里去了？本来以为敬汉卿事件过后这些公司会望而止步，结果万万没想到竟然还变本加厉！发国难财、侵犯他人的合法权益真的有意思吗？你们不为此而耻辱吗？ ('negative', 0.9999998668779311)
# 这个为什么会成每周必看啊 ('negative', 0.949435547796844)
# 这个视频有很多过万的up主评论 虽然我不知道抢注是什么意思 但看着挺生气的 ('negative', 0.9730125603140559)
# 加油！惩治不法分子 ('negative', 0.6444556884199983)
# 敬汉卿我喜欢你三年了，支持你加油！ ('positive', 0.6392143543326749)
# [热词系列_知识增加] ('positive', 0.5102694668302183)
# 无奈我没有币了。。。_x1f612_ ('negative', 0.8693108363970246)
# 两千万观看了！ ('negative', 0.8457523646386974)
# av90061118 ('positive', 0.5)
# 加油！奥利给！！！ ('negative', 0.5303804620183488)
# 1997年4月24曰（敬汉卿生日） ('negative', 0.6039438566022708)
# 名字都要被抢，多惨一男的[无语] ('negative', 0.9947190584654745)
# 镇 站 之 宝[吃瓜] ('negative', 0.8076894024812046)
# 加油加油加油 ('positive', 0.5857818265034096)
# ！！ ('negative', 0.5755185864796883)
